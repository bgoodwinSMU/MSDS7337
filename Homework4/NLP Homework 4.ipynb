# %% [markdown]
# ### NLP Homework 4
#
# #### By Ben Goodwin

# %%
#Import libraries
import nltk
from nltk.tokenize import word_tokenize

# %% [markdown]
# 1.	Run one of the part-of-speech (POS) taggers available in Python.
#
#     a.	Find the longest sentence you can, longer than 10 words, that the POS tagger tags correctly. Show the input and output.
#
#     b.	Find the shortest sentence you can, shorter than 10 words, that the POS tagger fails to tag 100 percent correctly. Show the input and output. Explain your conjecture as to why the tagger might have been less than perfect with this sentence.

# %% [markdown]
# Breakdown of POS tags
#
# CC: conjunction, coordinating
#
# DT: determiner
#
# IN: preposition or conjunction, subordinating
#
# JJ: adjective or numeral, ordinal
#
# JJR: adjective, comparative
#
# JJS: adjective, superlative
#
# LS: list item marker
#
# MD: modal auxiliary
#
# NN: noun, common, singular or mass
#
# NNP: noun, proper, singular
#
# NNS: noun, common, plural
#
# PDT: pre-determiner
#
# POS: genitive marker
#
# PRP: pronoun, personal
#
# PRP$: pronoun, possessive
#
# RB: adverb
#
# RBR: adverb, comparative
#
# RBS: adverb, superlative
#
# RP: particle
#
# TO: "to" as preposition or infinitive marker
#
# UH: interjection
#
# VB: verb, base form
#
# VBD: verb, past tense
#
# VBG: verb, present participle or gerund
#
# VBN: verb, past participle
#
# VBP: verb, present tense, not 3rd person singular
#
# VBZ: verb, present tense, 3rd person singular
#
# WDT: WH-determiner
#
# WP: WH-pronoun
#
# WRB: Wh-adverb

# %%
#A

#Input
#From GABRIEL GARCIA MARQUEZ, “AUTUMN OF THE PATRIARCH.” 121 WORDS.
text = word_tokenize("She had said I’m tired of begging God to overthrow my son, because all this business of living in the presidential palace is like having the lights on all the time, sir, and she had said it with the same naturalness with which on one national holiday she had made her way through the guard of honor with a basket of empty bottles and reached the presidential limousine that was leading the parade of celebration in an uproar of ovations and martial music and storms of flowers and she shoved the basket through the window and shouted to her son that since you’ll be passing right by take advantage and return these bottles to the store on the corner, poor mother.")

#Output below
nltk.pos_tag(text)
# Out:
# [('She', 'PRP'),
#  ('had', 'VBD'),
#  ('said', 'VBD'),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('m', 'RB'),
#  ('tired', 'VBN'),
#  ('of', 'IN'),
#  ('begging', 'VBG'),
#  ('God', 'NNP'),
#  ('to', 'TO'),
#  ('overthrow', 'VB'),
#  ('my', 'PRP$'),
#  ('son', 'NN'),
#  (',', ','),
#  ('because', 'IN'),
#  ('all', 'PDT'),
#  ('this', 'DT'),
#  ('business', 'NN'),
#  ('of', 'IN'),
#  ('living', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('presidential', 'JJ'),
#  ('palace', 'NN'),
#  ('is', 'VBZ'),
#  ('like', 'IN'),
#  ('having', 'VBG'),
#  ('the', 'DT'),
#  ('lights', 'NNS'),
#  ('on', 'IN'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  (',', ','),
#  ('sir', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('she', 'PRP'),
#  ('had', 'VBD'),
#  ('said', 'VBD'),
#  ('it', 'PRP'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('naturalness', 'NN'),
#  ('with', 'IN'),
#  ('which', 'WDT'),
#  ('on', 'IN'),
#  ('one', 'CD'),
#  ('national', 'JJ'),
# ...

# %%
#B

#Input
text = word_tokenize("The ski instructors ski in a race of skiing")
#Output
nltk.pos_tag(text)
# Out:
# [('The', 'DT'),
#  ('ski', 'JJ'),
#  ('instructors', 'NNS'),
#  ('ski', 'VBP'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('race', 'NN'),
#  ('of', 'IN'),
#  ('skiing', 'VBG')]

# %% [markdown]
# Commentary: Writing a short sentence that causes the POS tagger to fail was pretty difficult.  Luckily in NLTK there were a few examples of words that could potentially confuse the tagger.  These words were ski and race, both of these words can be used as a noun or verb.

# %% [markdown]
# 2.	Run a different POS tagger in Python. Process the same two sentences from question 1.
#
#
#     a.	Does it produce the same or different output?
#
#
#     b.	Explain any differences as best you can.

# %%
#Have to include this block as my python install was having issues identifying spacy

import sys
# !{sys.executable} -m pip install spacy
# Out:
# WARNING: Ignoring invalid distribution -ip (/Users/benjamingoodwin/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ip (/Users/benjamingoodwin/miniconda3/lib/python3.9/site-packages)
# ...
# WARNING: Ignoring invalid distribution -ip (/Users/benjamingoodwin/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ip (/Users/benjamingoodwin/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ip (/Users/benjamingoodwin/miniconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ip (/Users/benjamingoodwin/miniconda3/lib/python3.9/site-packages)
# WARNING: You are using pip version 21.1.2; however, version 22.0.3 is available.
# You should consider upgrading via the '/Users/benjamingoodwin/miniconda3/bin/python -m pip install --upgrade pip' command.
# ''

# %%
#Here is the different POS tagger for question 2
#Import spacy package
import spacy

#Load English library
nlp = spacy.load('en_core_web_sm')

#Load first string in 
str= '''"She had said I’m tired of begging God to overthrow my son, because all this business of living in the presidential palace is like having the lights on all the time, sir, and she had said it with the same naturalness with which on one national holiday she had made her way through the guard of honor with a basket of empty bottles and reached the presidential limousine that was leading the parade of celebration in an uproar of ovations and martial music and storms of flowers and she shoved the basket through the window and shouted to her son that since you’ll be passing right by take advantage and return these bottles to the store on the corner, poor mother."'''

#Load second string in
str2 = "The ski instructors ski in a race of skiing"

#Handle output
doc = nlp(str)
doc2 = nlp(str2)
for ent in doc:
      print(ent, ent.pos_)
print('')        
for ent2 in doc2:
    print(ent2, ent2.pos_)
# Out:
# " PUNCT
# She PRON
# had AUX
# said VERB
# I PRON
# ’m VERB
# tired ADJ
# of ADP
# begging VERB
# God PROPN
# to PART
# overthrow VERB
# my PRON
# son NOUN
# , PUNCT
# because SCONJ
# all DET
# this DET
# business NOUN
# of ADP
# living VERB
# in ADP
# the DET
# presidential ADJ
# palace NOUN
# is AUX
# like ADP
# having VERB
# the DET
# lights NOUN
# on ADP
# all DET
# the DET
# time NOUN
# , PUNCT
# sir PROPN
# , PUNCT
# and CCONJ
# she PRON
# had AUX
# said VERB
# it PRON
# with ADP
# the DET
# same ADJ
# naturalness NOUN
# with ADP
# which PRON
# on ADP
# one NUM
# national ADJ
# holiday NOUN
# she PRON
# had AUX
# made VERB
# her PRON
# way NOUN
# through ADP
# the DET
# guard NOUN
# of ADP
# honor NOUN
# with ADP
# a DET
# basket NOUN
# of ADP
# empty ADJ
# bottles NOUN
# and CCONJ
# reached VERB
# the DET
# presidential ADJ
# limousine NOUN
# that PRON
# was AUX
# leading VERB
# the DET
# parade NOUN
# of ADP
# celebration NOUN
# in ADP
# an DET
# uproar NOUN
# of ADP
# ...

# %% [markdown]
#  A)  Between NLTK and Spacy, I am finding that the outputs are different in both examples.
#
#
#
#  B) As I stated in question 1 of this question, the outputs are different.  I will focus on sentence two as it is shorter and the differences are more pronounced.
#
#  Take the second word in the sentence "ski," NLTK tagged this word as "JJ: adjective or numeral, ordinal" and Spacy tagged "ski" as a noun.  I can see how spacy tagged ski as both an adjective and a noun.  The word ski is a tricy one and can be a verb or a noun, in this case I used it as a noun, which spacy tagged correctly, but NLTK tagged it incorrectly.  I think I will attribute this to a poorly written sentence.
#
#
#
#
#  Interestingly, it turns out you can use Spacy to create custom rules

# %% [markdown]
# 3.	In a news article from this week’s news, find a random sentence of at least 10 words.
#
#     a.	Looking at the Penn tag set, manually POS tag the sentence yourself.
#
#
#     b.	Now run the same sentences through both taggers that you implemented for questions 1 and 2. Did either of the taggers produce the same results as you had created manually?
#
#
#     c.	Explain any differences between the two taggers and your manual tagging as much as you can.

# %% [markdown]
# Below is the sentence from this week:
#
#
# "Both adjoin Russia and have been controlled by Russian-backed fighters since 2014."

# %% [markdown]
#  A) Looking at the Penn tag set, I'll manualy tag the sentence...
#
#  "Both" DT
#  "adjoin" JJ
#  "Russia" NN
#  "and" CC
#  "have" VBP
#  "been" VBN
#  "controlled" VBN
#  "by" IN
#  "Russian-backed" JJ
#  "fighters" NNS
#  "since" IN
#  "2014" CD

# %%
#NLTK, Tagger 1

#Input
text = word_tokenize("Both adjoin Russia and have been controlled by Russian-backed fighters since 2014.")
#Output
nltk.pos_tag(text)
# Out:
# [('Both', 'DT'),
#  ('adjoin', 'JJ'),
#  ('Russia', 'NNP'),
#  ('and', 'CC'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('controlled', 'VBN'),
#  ('by', 'IN'),
#  ('Russian-backed', 'JJ'),
#  ('fighters', 'NNS'),
#  ('since', 'IN'),
#  ('2014', 'CD'),
#  ('.', '.')]

# %%
#Spacy, Tagger 2
#Load second string in
str2 = "Both adjoin Russia and have been controlled by Russian-backed fighters since 2014."

#Handle output
doc = nlp(str2)
for ent in doc:
      print(ent, ent.pos_)
# Out:
# Both PRON
# adjoin VERB
# Russia PROPN
# and CCONJ
# have AUX
# been AUX
# controlled VERB
# by ADP
# Russian PROPN
# - PUNCT
# backed VERB
# fighters NOUN
# since SCONJ
# 2014 NUM
# . PUNCT

# %% [markdown]
# Breakdown of the sentences and my commentary
#
# 1) "Both" by myself and NLTK said it is a determiner, while Spacy claims a personal pronoun
#
# 2) "adjoin" by myself and NLTK is an adjective, while spacy claims a verb
#
# 3) NLTK considered "Russia" as "NNS" which is a plural proper noun, which is mostly true except for the plural part.  My tagging and Spacy correctly cateogrized this.
#
# 4) conjunction, all around agreement
#
# 5) VBN Verb, past participle, VBP Verb, non-3rd person singular present for "have" and "been" while Spacy claims "aux"
#
# 6) verb, all around agreement
#
# 7) "In" Preposition or subordinating conjunction, agreement by myself and NLTK.  Spacy claims adverb which is clearly incorrecy
#
# 8) Russian, proper noun all around, NLTK tagged "plural" but other than that agreement
#
# 9) NLTK claimed adjective on "russian backed", as did I, Spacy broke out the phrase "Russian-backed" into proper noun and verb, which I think is an acceptable breakdown.
#
# 10) Fighters, all claimed as plural noun.
#
# 11) Spacy claims subordinating conjunction, while NLTK and I claim Preposition or subordinating conjunction, which match
#
# 12) All in agreement
#
# I think NLTK did a fine job tagging this sentence, I think that Spacy needs another training set.
